# %%
import numpy as np
import pandas as pd
from skimage.io import imshow, imsave
from matplotlib import pyplot as plt
from skimage.filters import gaussian

# %%
filters = np.load('/home/rt2122/data/one_patch_filters.npy')

# %%
filters.shape
# Out:
# (4096, 4096, 5)

# %%
def show_pic(pic, idx=[0, 1, 2], sigma=20, figsize=(20,20), dpi=80):
    g = pic[:,:,idx].copy()
    g = gaussian(g, sigma=sigma, multichannel=True)
    g -= g.min()
    g /= g.max()
    g *= 255
    plt.figure(figsize=figsize, dpi=dpi)
    imshow(g)
    return g

# %%
g = show_pic(filters, sigma=3, figsize=(30,30))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
filters.max()
# Out:
# 0.799048

# %%
sl = filters[:512,:512,:3].copy()

# %%
sl.shape
# Out:
# (512, 512, 3)

# %%
sl[sl == -4] = -1

# %%
sl -= sl.min()
sl /= sl.max()
sl *= 255

# %%
show_pic(sl, sigma=0)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imsave('gauss.png', g.astype(np.int32))

# %%
g.shape
# Out:
# (4096, 4096, 3)

# %%
g.max()
# Out:
# 55.575027
